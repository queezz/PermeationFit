# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os
import numpy as np

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
import ipywidgets as widgets
from ipywidgets import interact

# %%
def saddle(a=10,b=120):
    x = np.linspace(-1,1,100)
    y = np.linspace(-1,1,100)

    x,y = np.meshgrid(x,y)
    z = x**2 - y**2

    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    ax.plot_surface(x,y,z)
    ax.view_init(a,b)

interact(saddle,
         a=widgets.IntSlider(min=-180,max=180,step=1.,value=20),
         b=widgets.IntSlider(min=0,max=360,step=1.,value=45),)
# Out:
# interactive(children=(IntSlider(value=20, description='a', max=180, min=-180), IntSlider(value=45, description…
# <function __main__.saddle(a=10, b=120)>

# %%
x = np.linspace(0,2,100)
y = (x-1)**2 - 0.1*x**3
plot(x,y)

# %%
def poli(a,b,c,d,x0):
    x = np.linspace(0,1,100)
    y = a*(x-x0)**3 + b*(x-x0)**2 + c*(x-x0) + d
    plot(x,y)
    
interact(poli,
         a=widgets.FloatSlider(min=-10,max=10,value = 1),
         b=widgets.FloatSlider(min=-10,max=10.,value=1),
         c=widgets.FloatSlider(min=-10,max=10.,value=1),
         d=widgets.FloatSlider(min=-10,max=10,value=1),
         x0=widgets.FloatSlider(min=0,max=1,value=0),
        )
# Out:
# interactive(children=(FloatSlider(value=1.0, description='a', max=10.0, min=-10.0), FloatSlider(value=1.0, des…
# <function __main__.poli(a, b, c, d, x0)>

# %%
x = np.linspace(0,1,1000)
y = 3*x**3 - 3.5*x**2 + x
plot(x,y)

# %%
yp = np.gradient(y,x)
ypp = np.gradient(yp,x)
#plot(x,ypp)
plot(x,yp)
#plot(x,y)
axhline(0,ls='--',lw=1,c='k')
